# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import geopandas as gpd
import seaborn as sns
from matplotlib.ticker import ScalarFormatter
import rioxarray as rxr
from datetime import datetime
import glob
import os
import contextily as ctx
import xarray
from collections import Counter
import cmcrameri.cm as cmc
import shutil

from working_sca_funcs import *

# %%
# Define year you are working on
year = '2023'

# Define basin you are working on
name = 'DLNY'
# name = 'BUDD'

# Define model you are working on
# model = 'V5' # 2022 BUDD ASO 2 class
# model = 'V7' # 2022 BUDD manual classification snow/no snow trained on set of images and artifacts on different images
model = 'V9'

# raw PS images
ps_raw = f'/data0/images/planet/emma/planet/{name}/'
# ps_raw_subdir = sorted([d for d in glob.glob(ps_raw + str(year) + '*') if os.path.isdir(d)])
ps_raw_subdir = sorted([d for d in glob.glob(ps_raw + '*') if os.path.isdir(d)])

# SCA directory
ps_sca_dir = f'/home/etboud/projects/data/rerun/{name}/{model}/'
# ps_sca_tif = glob.glob(ps_sca_dir + f'*{year}*.tif')
ps_sca_tif = glob.glob(ps_sca_dir + '*.tif')

# ASO directory
aso_dir = f'/home/etboud/projects/data/aso/validation/{name}/V2/'
# aso_tif = glob.glob(os.path.join(aso_dir, f'*{year}*3m*.tif')) 
aso_tif = glob.glob(os.path.join(aso_dir, '*3m*.tif'))

# Create basin shapefile
BS = f'/home/etboud/projects/data/basins/{name}/{name}_4326.geojson'
basin = gpd.read_file(BS)
basin = basin.to_crs('EPSG:32611') 

# Extract dates from file names
ps_dates = extract_dates([], ps_sca_tif)[1]  
aso_dates = extract_dates(aso_tif, [])[0]

# canopy height model
CHM = '/home/etboud/projects/data/CHM/USCATB20140827_chm_3p0m.tif'

# %% [markdown]
# ### Move scenes around

# %%
# Run for each Basin to create list of scenes to keep

dir =  glob.glob(f'/home/etboud/projects/data/rerun/{name}/V5/'+'*.tif')
save_good = []
for file in dir:
    fn = os.path.basename(file)
    save_good.append(fn)

# %%
# Move processed bad files to a new directory
other_model = 'V9'
path = f'/home/etboud/projects/data/rerun/{name}/{other_model}/'
move_to = f'/home/etboud/projects/data/rerun/{name}/{other_model}/not_good/'
dir = glob.glob(path + '/*.tif')
for file in dir:
    if os.path.basename(file) not in save_good:
        print(file)
        src = path+os.path.basename(file)
        dst = move_to+os.path.basename(file)
        shutil.move(src, dst)
# Out:
# /home/etboud/projects/data/rerun/DLNY/V9/20220829_174345_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230405_174458_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20220924_181922_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230621_174946_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230928_182711_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230823_175403_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230829_183116_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230710_182903_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230912_175511_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230402_182234_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20220601_182009_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230723_175313_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20220923_174646_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230416_182322_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230515_182302_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230329_174848_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20220916_181937_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230901_175130_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230605_175356_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20220928_174306_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230923_175518_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230429_174945_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230727_174538_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230710_182906_SCA.tif
# /home/etboud/projects/data/rerun/DLNY/V9/20230720_182819_SCA.tif

# %%
print(len(glob.glob('/home/etboud/projects/data/rerun/BUDD/V5' + '/*2022*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/BUDD/V9' + '/*2022*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/BUDD/V7' + '/*2022*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/BUDD/V5' + '/*2023*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/BUDD/V9' + '/*2023*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/BUDD/V7' + '/*2023*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/DLNY/V5' + '/*2023*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/DLNY/V9' + '/*2023*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/DLNY/V7' + '/*2023*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/DLNY/V7' + '/*2022*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/DLNY/V5' + '/*2022*.tif')))
print(len(glob.glob('/home/etboud/projects/data/rerun/DLNY/V9' + '/*2022*.tif')))
# Out:
# 82
# 82
# 82
# 69
# 69
# 69
# 77
# 77
# 77
# 92
# 92
# 92

# %% [markdown]
# ## Looking at NOT good files

# %%
# Run for each Basin to create a list of PS scenes that are bad
# Run this when model is set to V1 (unobs scenes already in not_good model)
dir =  glob.glob(f'/home/etboud/projects/data/rerun/{name}/V5/not_good/'+'*.tif')
save_bad = []
for file in dir:
    fn = os.path.basename(file)
    save_bad.append(fn)
        
# for file in dir:
#     if os.path.basename(file)[:4]==year:
#         fn = os.path.basename(file)
#         save_bad.append(fn)

# %%
# Plot 'not_good' scenes
not_good = f'/home/etboud/projects/data/rerun/{name}/V5/not_good/'
dir = glob.glob(not_good + '/*.tif')
for file in dir:
    fn = os.path.basename(file)
    date = fn.split('_')[0]
    id = fn.split('_')[1]
    code = f'{date}_{id}'

    for raw_file in ps_raw_subdir:
        if code in raw_file:
            matching_raw_file = glob.glob(raw_file+'/*/PSScene/*_SR_clip.tif')[0]
            rgb_image = rioxarray.open_rasterio(matching_raw_file,masked = True, drop=True)
            rgb_image = rgb_image.rio.clip(basin.geometry, basin.crs)
            _, _, _, _, rgb_image = calc_rgb(rgb_image)
            
            sca = rioxarray.open_rasterio(file, all_touched=False, drop=True, masked=True)
            sca.values = np.where(np.isnan(sca.values), 0, sca.values)
            sca = sca.rio.clip(basin.geometry.values, crs=basin.crs, drop=True)
            sca = np.squeeze(sca.values)
            
            plt.subplot(1,2,1)
            plt.imshow(sca,vmin= 0,vmax = 2, interpolation= 'none')
            plt.colorbar()
            plt.title(code)
            plt.axis('off')
            
            plt.subplot(1,2,2)
            plt.imshow(rgb_image)
            plt.axis('off')
            plt.show()

# %% [markdown]
# ### Determining NOT GOOD

# %%
# Plot  scenes
# File path to processed SCA which no scenes have been filitered out
file_path = f'/home/etboud/projects/data/rerun/{name}/V5/'
dir = glob.glob(file_path + '/*.tif')
for file in dir:
    fn = os.path.basename(file)
    date = fn.split('_')[0]
    id = fn.split('_')[1]
    code = f'{date}_{id}'

    for raw_file in ps_raw_subdir:
        if code in raw_file:
            matching_raw_file = glob.glob(raw_file+'/*/PSScene/*_SR_clip.tif')[0]
            rgb_image = rioxarray.open_rasterio(matching_raw_file,masked = True, drop=True)
            rgb_image = rgb_image.rio.clip(basin.geometry, basin.crs)
            _, _, _, _, rgb_image = calc_rgb(rgb_image)
            
            sca = rioxarray.open_rasterio(file, all_touched=False, drop=True, masked=True)
            sca.values = np.where(np.isnan(sca.values), 0, sca.values)
            sca = sca.rio.clip(basin.geometry.values, crs=basin.crs, drop=True)
            sca = np.squeeze(sca.values)
            
            plt.subplot(1,2,1)
            plt.imshow(sca,vmin= 0,vmax = 2, interpolation= 'none')
            plt.colorbar()
            plt.title(code)
            plt.axis('off')
            
            plt.subplot(1,2,2)
            plt.imshow(rgb_image)
            plt.axis('off')
            plt.show()

# %% [markdown]
# ### IF moving raw images

# %%
# #moving raw subdirectories for bad PS images to a different directory
# path = f'/data0/images/planet/emma/planet/{name}/'
# move_to = f'/data0/images/planet/emma/planet/{name}/not_good/'
# dir = glob.glob(path + '/*.tif')
# save_bad_codes = [fn.split('_')[0] + '_' + fn.split('_')[1] for fn in save_bad]

# for file in ps_raw_subdir:
#     fn = os.path.basename(file)
#     date = fn.split('_')[0]
#     id = fn.split('_')[1]
#     code = f'{date}_{id}'
#     subdir = file.split('/')[-1]
#     if code in save_bad_codes:
#         src = path+subdir
#         dst = move_to+subdir
#         shutil.move(src, dst)
#         # print(subdir)

# %% [markdown]
# ## Save corresponding files

# %%
def closest_dates(ps_dates, aso_date):
    # Extract dates from tuples
    ps_date_list = [date for date, _ in ps_dates]
    # Sort the ps_dates
    sorted_list = sorted(ps_date_list)
    
    closest_distance = None
    closest_dates = []

    for date in sorted_list:
        distance = abs((date - aso_date).days)
        
        if closest_distance is None or distance < closest_distance:
            closest_distance = distance
            closest_dates = [date]
        elif distance == closest_distance:
            closest_dates.append(date)

    return closest_dates

# %%
name
# Out:
# 'DLNY'

# %%
# create dataframe to store all PS filenames with corresponding ASO flights
raw_fn = []
for aso_date, aso_file in sorted(aso_dates):
    closest = closest_dates(ps_dates, aso_date)

    closest_str = closest[0].strftime('%Y%m%d') # change index fromo to -1 to get the preceeding or following closest date when dates adjacent are equadistance
    # ps_dates = pd.to_datetime(closest_str, format='%Y-%m-%d') 
    print(closest_str)
    for fn in ps_sca_tif:
        if closest_str in fn:
            matching_model_files = glob.glob(fn)
            code = fn.split('/')[-1].split('_')[1]
            closest_code = f'{closest_str}_{code}'
    for file in ps_raw_subdir:
        if closest_code in file:
            matching_raw_files = glob.glob(file+'/*/PSScene/*_SR_clip.tif')[0]
            raw_fn.append({"date": closest_str, "raw_file": matching_raw_files,"model_file": matching_model_files, "aso_file": aso_file,"aso_date": aso_date})
            
pd_dlny_0 = pd.DataFrame(raw_fn)
# Out:
# 20220405
# 20220429
# 20220519
# 20230426
# 20230601
# 20230629

# %%
merged = pd.concat([pd_dlny_0,pd_dlny_1,pd_budd_0,pd_budd_1], ignore_index=True) #run in different cell after creating multiple DF for each year

# %%
def clean_string(x):
    if isinstance(x, list):
        # Convert list to string, then clean it
        x = ', '.join(map(str, x))
    elif not isinstance(x, str):
        return x  # Return as is if not a string or list

    # Now x is guaranteed to be a string, so we can clean it
    return x.replace('[', '').replace(']', '').replace("'", '')

# Apply the cleaning function to both columns
merged['raw_file'] = merged['raw_file'].apply(clean_string)
merged['model_file'] = merged['model_file'].apply(clean_string)

# Format date columns
merged['ps_date'] = pd.to_datetime(merged['date']).dt.strftime('%Y-%m-%d')
merged['aso_date'] = pd.to_datetime(merged['aso_date']).dt.strftime('%Y-%m-%d')
merged['model_run'] = merged['model_file'].str.split('/').str[-2]
# Drop the original date column
merged.drop(columns=['date'], inplace=True)
merged_drop = merged.drop_duplicates()
# merged_drop.to_csv('corresponding_files.csv', index=False)

# %%
# Loop through the corresponding files
for index, row in merged_drop.iterrows():
    raw_fn = row['raw_file']
    model_fn = row['model_file']
    aso_fn = row['aso_file']
    
    fn = raw_fn.split('/')[-1].split('_')
    id = f'{fn[0]}_{fn[1]}'
    name = model_fn.split('/')[-3]
    basin = gpd.read_file(f'/home/etboud/projects/data/basins/{name}/{name}_4326.geojson')
    basin = basin.to_crs('EPSG:32611')
    rgb_image = rxr.open_rasterio(raw_fn,masked = True, drop=True)
    rgb_image = rgb_image.rio.clip(basin.geometry, basin.crs)
    _, _, _, _, rgb_image = calc_rgb(rgb_image)

    
    model_image = rxr.open_rasterio(model_fn, masked=True, drop=True)
    model_image.values = np.where(np.isnan(model_image.values), 0, model_image.values)
    model_image = model_image.rio.clip(basin.geometry, basin.crs)
    
    aso = rxr.open_rasterio(aso_fn, masked=True)
    
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 4, 1)
    plt.imshow(rgb_image)
    plt.title(f'RGB Image {id}')
    plt.axis('off')

    # Original Image
    plt.subplot(1, 4, 2)
    plt.imshow(model_image[0], interpolation ='none', cmap='Blues',vmin = 0, vmax = 1)
    plt.title('Model Output')
    plt.axis('off')


    # Convolved Output
    plt.subplot(1, 4, 3)
    plt.imshow(aso[0], interpolation='none', cmap='Blues',vmin = 0,vmax=1)
    plt.title(row['aso_date'])
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
corr_files = pd.read_csv('corresponding_files.csv')

# %%
corr_files
# Out:
#                                              raw_file  \
# 0   /data0/images/planet/emma/planet/DLNY/20220405...
# 1   /data0/images/planet/emma/planet/DLNY/20220429...
# 2   /data0/images/planet/emma/planet/DLNY/20220519...
# 3   /data0/images/planet/emma/planet/DLNY/20230426...
# 4   /data0/images/planet/emma/planet/DLNY/20230601...
# 5   /data0/images/planet/emma/planet/DLNY/20230629...
# 6   /data0/images/planet/emma/planet/BUDD/20220403...
# 7   /data0/images/planet/emma/planet/BUDD/20220430...
# 8   /data0/images/planet/emma/planet/BUDD/20220518...
# 9   /data0/images/planet/emma/planet/BUDD/20230426...
# 10  /data0/images/planet/emma/planet/BUDD/20230601...
# 11  /data0/images/planet/emma/planet/BUDD/20230629...
# 12  /data0/images/planet/emma/planet/BUDD/20220407...
# 13  /data0/images/planet/emma/planet/DLNY/20220405...
# 14  /data0/images/planet/emma/planet/DLNY/20220429...
# 15  /data0/images/planet/emma/planet/DLNY/20220519...
# 16  /data0/images/planet/emma/planet/DLNY/20230426...
# 17  /data0/images/planet/emma/planet/DLNY/20230601...
# 18  /data0/images/planet/emma/planet/DLNY/20230629...
# 19  /data0/images/planet/emma/planet/BUDD/20220403...
# 20  /data0/images/planet/emma/planet/BUDD/20220430...
# 21  /data0/images/planet/emma/planet/BUDD/20220518...
# 22  /data0/images/planet/emma/planet/BUDD/20230426...
# 23  /data0/images/planet/emma/planet/BUDD/20230601...
# 24  /data0/images/planet/emma/planet/BUDD/20230629...
# 25  /data0/images/planet/emma/planet/BUDD/20220407...
#
#                                            model_file  \
# 0   /home/etboud/projects/data/rerun/DLNY/V7/20220...
# 1   /home/etboud/projects/data/rerun/DLNY/V7/20220...
# 2   /home/etboud/projects/data/rerun/DLNY/V7/20220...
# 3   /home/etboud/projects/data/rerun/DLNY/V7/20230...
# 4   /home/etboud/projects/data/rerun/DLNY/V7/20230...
# 5   /home/etboud/projects/data/rerun/DLNY/V7/20230...
# 6   /home/etboud/projects/data/rerun/BUDD/V7/20220...
# 7   /home/etboud/projects/data/rerun/BUDD/V7/20220...
# 8   /home/etboud/projects/data/rerun/BUDD/V7/20220...
# 9   /home/etboud/projects/data/rerun/BUDD/V7/20230...
# 10  /home/etboud/projects/data/rerun/BUDD/V7/20230...
# 11  /home/etboud/projects/data/rerun/BUDD/V7/20230...
# 12  /home/etboud/projects/data/rerun/BUDD/V7/20220...
# 13  /home/etboud/projects/data/rerun/DLNY/V5/20220...
# 14  /home/etboud/projects/data/rerun/DLNY/V5/20220...
# 15  /home/etboud/projects/data/rerun/DLNY/V5/20220...
# 16  /home/etboud/projects/data/rerun/DLNY/V5/20230...
# 17  /home/etboud/projects/data/rerun/DLNY/V5/20230...
# 18  /home/etboud/projects/data/rerun/DLNY/V5/20230...
# 19  /home/etboud/projects/data/rerun/BUDD/V5/20220...
# 20  /home/etboud/projects/data/rerun/BUDD/V5/20220...
# 21  /home/etboud/projects/data/rerun/BUDD/V5/20220...
# 22  /home/etboud/projects/data/rerun/BUDD/V5/20230...
# 23  /home/etboud/projects/data/rerun/BUDD/V5/20230...
# 24  /home/etboud/projects/data/rerun/BUDD/V5/20230...
# 25  /home/etboud/projects/data/rerun/BUDD/V5/20220...
#
#                                              aso_file    aso_date     ps_date  \
# 0   /home/etboud/projects/data/aso/validation/DLNY...  2022-04-05  2022-04-05
# 1   /home/etboud/projects/data/aso/validation/DLNY...  2022-04-29  2022-04-29
# 2   /home/etboud/projects/data/aso/validation/DLNY...  2022-05-18  2022-05-19
# 3   /home/etboud/projects/data/aso/validation/DLNY...  2023-04-27  2023-04-26
# 4   /home/etboud/projects/data/aso/validation/DLNY...  2023-06-01  2023-06-01
# 5   /home/etboud/projects/data/aso/validation/DLNY...  2023-06-26  2023-06-29
# 6   /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-03
# 7   /home/etboud/projects/data/aso/validation/BUDD...  2022-04-29  2022-04-30
# 8   /home/etboud/projects/data/aso/validation/BUDD...  2022-05-18  2022-05-18
# 9   /home/etboud/projects/data/aso/validation/BUDD...  2023-04-27  2023-04-26
# 10  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-01  2023-06-01
# 11  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-26  2023-06-29
# 12  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-07
# 13  /home/etboud/projects/data/aso/validation/DLNY...  2022-04-05  2022-04-05
# 14  /home/etboud/projects/data/aso/validation/DLNY...  2022-04-29  2022-04-29
# 15  /home/etboud/projects/data/aso/validation/DLNY...  2022-05-18  2022-05-19
# 16  /home/etboud/projects/data/aso/validation/DLNY...  2023-04-27  2023-04-26
# 17  /home/etboud/projects/data/aso/validation/DLNY...  2023-06-01  2023-06-01
# 18  /home/etboud/projects/data/aso/validation/DLNY...  2023-06-26  2023-06-29
# 19  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-03
# 20  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-29  2022-04-30
# 21  /home/etboud/projects/data/aso/validation/BUDD...  2022-05-18  2022-05-18
# 22  /home/etboud/projects/data/aso/validation/BUDD...  2023-04-27  2023-04-26
# 23  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-01  2023-06-01
# 24  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-26  2023-06-29
# 25  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-07
#
#    model_run
# 0         V7
# 1         V7
# 2         V7
# 3         V7
# 4         V7
# 5         V7
# 6         V7
# 7         V7
# 8         V7
# 9         V7
# 10        V7
# 11        V7
# 12        V7
# 13        V5
# 14        V5
# 15        V5
# 16        V5
# 17        V5
# 18        V5
# 19        V5
# 20        V5
# 21        V5
# 22        V5
# 23        V5
# 24        V5
# 25        V5

# %%
update = pd.concat([corr_files,merged_drop], ignore_index=True)

# %%
update
# Out:
#                                              raw_file  \
# 0   /data0/images/planet/emma/planet/DLNY/20220405...
# 1   /data0/images/planet/emma/planet/DLNY/20220429...
# 2   /data0/images/planet/emma/planet/DLNY/20220519...
# 3   /data0/images/planet/emma/planet/DLNY/20230426...
# 4   /data0/images/planet/emma/planet/DLNY/20230601...
# 5   /data0/images/planet/emma/planet/DLNY/20230629...
# 6   /data0/images/planet/emma/planet/BUDD/20220403...
# 7   /data0/images/planet/emma/planet/BUDD/20220430...
# 8   /data0/images/planet/emma/planet/BUDD/20220518...
# 9   /data0/images/planet/emma/planet/BUDD/20230426...
# 10  /data0/images/planet/emma/planet/BUDD/20230601...
# 11  /data0/images/planet/emma/planet/BUDD/20230629...
# 12  /data0/images/planet/emma/planet/BUDD/20220407...
# 13  /data0/images/planet/emma/planet/DLNY/20220405...
# 14  /data0/images/planet/emma/planet/DLNY/20220429...
# 15  /data0/images/planet/emma/planet/DLNY/20220519...
# 16  /data0/images/planet/emma/planet/DLNY/20230426...
# 17  /data0/images/planet/emma/planet/DLNY/20230601...
# 18  /data0/images/planet/emma/planet/DLNY/20230629...
# 19  /data0/images/planet/emma/planet/BUDD/20220403...
# 20  /data0/images/planet/emma/planet/BUDD/20220430...
# 21  /data0/images/planet/emma/planet/BUDD/20220518...
# 22  /data0/images/planet/emma/planet/BUDD/20230426...
# 23  /data0/images/planet/emma/planet/BUDD/20230601...
# 24  /data0/images/planet/emma/planet/BUDD/20230629...
# 25  /data0/images/planet/emma/planet/BUDD/20220407...
# 26  /data0/images/planet/emma/planet/DLNY/20220405...
# 27  /data0/images/planet/emma/planet/DLNY/20220429...
# 28  /data0/images/planet/emma/planet/DLNY/20220519...
# 29  /data0/images/planet/emma/planet/DLNY/20230426...
# 30  /data0/images/planet/emma/planet/DLNY/20230601...
# 31  /data0/images/planet/emma/planet/DLNY/20230629...
# 32  /data0/images/planet/emma/planet/BUDD/20220403...
# 33  /data0/images/planet/emma/planet/BUDD/20220430...
# 34  /data0/images/planet/emma/planet/BUDD/20220518...
# 35  /data0/images/planet/emma/planet/BUDD/20230426...
# 36  /data0/images/planet/emma/planet/BUDD/20230601...
# 37  /data0/images/planet/emma/planet/BUDD/20230629...
# 38  /data0/images/planet/emma/planet/BUDD/20220407...
#
#                                            model_file  \
# 0   /home/etboud/projects/data/rerun/DLNY/V7/20220...
# 1   /home/etboud/projects/data/rerun/DLNY/V7/20220...
# 2   /home/etboud/projects/data/rerun/DLNY/V7/20220...
# 3   /home/etboud/projects/data/rerun/DLNY/V7/20230...
# 4   /home/etboud/projects/data/rerun/DLNY/V7/20230...
# 5   /home/etboud/projects/data/rerun/DLNY/V7/20230...
# 6   /home/etboud/projects/data/rerun/BUDD/V7/20220...
# 7   /home/etboud/projects/data/rerun/BUDD/V7/20220...
# 8   /home/etboud/projects/data/rerun/BUDD/V7/20220...
# 9   /home/etboud/projects/data/rerun/BUDD/V7/20230...
# 10  /home/etboud/projects/data/rerun/BUDD/V7/20230...
# 11  /home/etboud/projects/data/rerun/BUDD/V7/20230...
# 12  /home/etboud/projects/data/rerun/BUDD/V7/20220...
# 13  /home/etboud/projects/data/rerun/DLNY/V5/20220...
# 14  /home/etboud/projects/data/rerun/DLNY/V5/20220...
# 15  /home/etboud/projects/data/rerun/DLNY/V5/20220...
# 16  /home/etboud/projects/data/rerun/DLNY/V5/20230...
# 17  /home/etboud/projects/data/rerun/DLNY/V5/20230...
# 18  /home/etboud/projects/data/rerun/DLNY/V5/20230...
# 19  /home/etboud/projects/data/rerun/BUDD/V5/20220...
# 20  /home/etboud/projects/data/rerun/BUDD/V5/20220...
# 21  /home/etboud/projects/data/rerun/BUDD/V5/20220...
# 22  /home/etboud/projects/data/rerun/BUDD/V5/20230...
# 23  /home/etboud/projects/data/rerun/BUDD/V5/20230...
# 24  /home/etboud/projects/data/rerun/BUDD/V5/20230...
# 25  /home/etboud/projects/data/rerun/BUDD/V5/20220...
# 26  /home/etboud/projects/data/rerun/DLNY/V9/20220...
# 27  /home/etboud/projects/data/rerun/DLNY/V9/20220...
# 28  /home/etboud/projects/data/rerun/DLNY/V9/20220...
# 29  /home/etboud/projects/data/rerun/DLNY/V9/20230...
# 30  /home/etboud/projects/data/rerun/DLNY/V9/20230...
# 31  /home/etboud/projects/data/rerun/DLNY/V9/20230...
# 32  /home/etboud/projects/data/rerun/BUDD/V9/20220...
# 33  /home/etboud/projects/data/rerun/BUDD/V9/20220...
# 34  /home/etboud/projects/data/rerun/BUDD/V9/20220...
# 35  /home/etboud/projects/data/rerun/BUDD/V9/20230...
# 36  /home/etboud/projects/data/rerun/BUDD/V9/20230...
# 37  /home/etboud/projects/data/rerun/BUDD/V9/20230...
# 38  /home/etboud/projects/data/rerun/BUDD/V9/20220...
#
#                                              aso_file    aso_date     ps_date  \
# 0   /home/etboud/projects/data/aso/validation/DLNY...  2022-04-05  2022-04-05
# 1   /home/etboud/projects/data/aso/validation/DLNY...  2022-04-29  2022-04-29
# 2   /home/etboud/projects/data/aso/validation/DLNY...  2022-05-18  2022-05-19
# 3   /home/etboud/projects/data/aso/validation/DLNY...  2023-04-27  2023-04-26
# 4   /home/etboud/projects/data/aso/validation/DLNY...  2023-06-01  2023-06-01
# 5   /home/etboud/projects/data/aso/validation/DLNY...  2023-06-26  2023-06-29
# 6   /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-03
# 7   /home/etboud/projects/data/aso/validation/BUDD...  2022-04-29  2022-04-30
# 8   /home/etboud/projects/data/aso/validation/BUDD...  2022-05-18  2022-05-18
# 9   /home/etboud/projects/data/aso/validation/BUDD...  2023-04-27  2023-04-26
# 10  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-01  2023-06-01
# 11  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-26  2023-06-29
# 12  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-07
# 13  /home/etboud/projects/data/aso/validation/DLNY...  2022-04-05  2022-04-05
# 14  /home/etboud/projects/data/aso/validation/DLNY...  2022-04-29  2022-04-29
# 15  /home/etboud/projects/data/aso/validation/DLNY...  2022-05-18  2022-05-19
# 16  /home/etboud/projects/data/aso/validation/DLNY...  2023-04-27  2023-04-26
# 17  /home/etboud/projects/data/aso/validation/DLNY...  2023-06-01  2023-06-01
# 18  /home/etboud/projects/data/aso/validation/DLNY...  2023-06-26  2023-06-29
# 19  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-03
# 20  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-29  2022-04-30
# 21  /home/etboud/projects/data/aso/validation/BUDD...  2022-05-18  2022-05-18
# 22  /home/etboud/projects/data/aso/validation/BUDD...  2023-04-27  2023-04-26
# 23  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-01  2023-06-01
# 24  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-26  2023-06-29
# 25  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-07
# 26  /home/etboud/projects/data/aso/validation/DLNY...  2022-04-05  2022-04-05
# 27  /home/etboud/projects/data/aso/validation/DLNY...  2022-04-29  2022-04-29
# 28  /home/etboud/projects/data/aso/validation/DLNY...  2022-05-18  2022-05-19
# 29  /home/etboud/projects/data/aso/validation/DLNY...  2023-04-27  2023-04-26
# 30  /home/etboud/projects/data/aso/validation/DLNY...  2023-06-01  2023-06-01
# 31  /home/etboud/projects/data/aso/validation/DLNY...  2023-06-26  2023-06-29
# 32  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-03
# 33  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-29  2022-04-30
# 34  /home/etboud/projects/data/aso/validation/BUDD...  2022-05-18  2022-05-18
# 35  /home/etboud/projects/data/aso/validation/BUDD...  2023-04-27  2023-04-26
# 36  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-01  2023-06-01
# 37  /home/etboud/projects/data/aso/validation/BUDD...  2023-06-26  2023-06-29
# 38  /home/etboud/projects/data/aso/validation/BUDD...  2022-04-05  2022-04-07
#
#    model_run
# 0         V7
# 1         V7
# 2         V7
# 3         V7
# 4         V7
# 5         V7
# 6         V7
# 7         V7
# 8         V7
# 9         V7
# 10        V7
# 11        V7
# 12        V7
# 13        V5
# 14        V5
# 15        V5
# 16        V5
# 17        V5
# 18        V5
# 19        V5
# 20        V5
# 21        V5
# 22        V5
# 23        V5
# 24        V5
# 25        V5
# 26        V9
# 27        V9
# 28        V9
# 29        V9
# 30        V9
# 31        V9
# 32        V9
# 33        V9
# 34        V9
# 35        V9
# 36        V9
# 37        V9
# 38        V9

# %%
update.to_csv('corresponding_files.csv', index=False)
